# %%
# !pip install numpy
# !pip install pandas
# !pip install matplotlib
# !pip install seaborn
# Out:
# ...
#
# [notice] A new release of pip is available: 25.0.1 -> 25.2
# [notice] To update, run: pip install --upgrade pip
# ...
#
# [notice] A new release of pip is available: 25.0.1 -> 25.2
# [notice] To update, run: pip install --upgrade pip
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 5.9 MB/s eta 0:00:00a 0:00:01
# ...
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 6.0 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 5.6 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 4.9 MB/s eta 0:00:00a 0:00:01
# ...
#
# [notice] A new release of pip is available: 25.0.1 -> 25.2
# [notice] To update, run: pip install --upgrade pip
# ...
#
# [notice] A new release of pip is available: 25.0.1 -> 25.2
# [notice] To update, run: pip install --upgrade pip

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
# BLOCK 1
# Visualise freq tables, explore them
# READ THE TABLES

#conllu fields
cat_list = ['id', 'form', 'lemma', 'upos', 'xpos', 'feats', 'head', 'deprel', 'deps', 'misc']

conllu_d={}
for cat in cat_list:
    infile = f"freqs_{cat}.csv"
    conllu_d[cat]=pd.read_csv("eval/freq/"+infile)
    #conllu_d[cat]=np.genfromtxt("eval/freq/"+infile, delimiter=",", skip_header=1) #-> this works too but has no headers :(

df=conllu_d["lemma"]

# %%
df1=df.drop("filename", axis=1).drop("category", axis=1)
print(df)
# Out:
#                           filename category   rel        un  conductor  \
# 0      tv3_corpus_10_russia.conllu    lemma  4672  1.904966   0.042808
# 1  KI_corpus_10_russia_gemm.conllu    lemma  4222  2.723828   0.023685
#
#         rus     haver  confondre    Moscou       amb  ...    balanç  \
# 0  0.556507  2.268836   0.021404  0.235445  0.599315  ...       NaN
# 1  0.639507  2.463288        NaN  0.142113  0.568451  ...  0.023685
#
#    progresso  realitzat   pendent      camí  continuat  involucrat    Govern  \
# 0        NaN        NaN       NaN       NaN        NaN         NaN       NaN
# 1   0.023685   0.023685  0.023685  0.023685   0.023685    0.023685  0.023685
#
#    reiterar  solidaritat
# 0       NaN          NaN
# 1  0.023685     0.023685
#
# [2 rows x 1753 columns]

# %%
df1.info()
print(df1.select_dtypes(include='object'))
#print(df.sort_values(axis= 1, by=1, ascending=False, na_position="last"))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Columns: 1751 entries, rel to solidaritat
# dtypes: float64(1750), int64(1)
# memory usage: 27.5 KB
# Empty DataFrame
# Columns: []
# Index: [0, 1]

# %%
sorted= df1.sort_values(axis=1, by=0, ascending=False, na_position='last')
print(df1.sort_values(axis=1, by=0, ascending=False, na_position='last'))
# Out:
#     rel         el        de         ,         .         a       que  \
# 0  4672  11.151541  7.534247  4.687500  4.152397  3.745719  2.482877
# 1  4222  12.695405  7.247750  4.950261  3.576504  3.221222  1.965893
#
#       haver         i        un  ...    balanç  progresso  realitzat  \
# 0  2.268836  2.119007  1.904966  ...       NaN        NaN        NaN
# 1  2.463288  2.747513  2.723828  ...  0.023685   0.023685   0.023685
#
#     pendent      camí  continuat  involucrat    Govern  reiterar  solidaritat
# 0       NaN       NaN        NaN         NaN       NaN       NaN          NaN
# 1  0.023685  0.023685   0.023685    0.023685  0.023685  0.023685     0.023685
#
# [2 rows x 1751 columns]

# %%
# Out:
# rel            4672.000000
# un                1.904966
# conductor         0.042808
# rus               0.556507
# haver             2.268836
#                   ...
# continuat              NaN
# involucrat             NaN
# Govern                 NaN
# reiterar               NaN
# solidaritat            NaN
# Name: 0, Length: 1751, dtype: float64
